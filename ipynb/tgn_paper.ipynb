# %%
# !git clone https://github.com/twitter-research/tgn
# %cd tgn
# Out:
# Cloning into 'tgn'...
# remote: Enumerating objects: 180, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 180 (delta 82), reused 77 (delta 77), pack-reused 77 (from 1)
# Receiving objects: 100% (180/180), 976.40 KiB | 16.01 MiB/s, done.
# Resolving deltas: 100% (94/94), done.
# /content/tgn

# %% [markdown]
# TGN requires PyTorch and other graph-related libraries. Install using:

# %%
# !mkdir data

# %%
#!pip install torch torchvision torchaudio
#!pip install numpy pandas tqdm
#!pip install networkx scikit-learn

# %% [markdown]
# TGN uses PyTorch Geometric, so install it with the following

# %%
#!pip install torch-geometric torch-sparse torch-scatter torch-cluster torch-spline-conv

# %%
import pandas as pd

df = pd.read_csv("data/wikipedia.csv",skiprows=1, header=None)
lengths = df.iloc[:, 4:].apply(lambda row: len(row.dropna()), axis=1)
print(lengths.value_counts())
# Out:
# 172    105591
# 23          1
# Name: count, dtype: int64

# %%
# !python3 utils/preprocess_data.py --data wikipedia --bipartite

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# %cd /content/tgn
# !python3 train_self_supervised.py --use_memory --prefix tgn-attn --n_runs 3
# Out:
# /content/tgn
# INFO:root:Namespace(data='wikipedia', bs=200, prefix='tgn-attn', n_degree=10, n_head=2, n_epoch=50, n_layer=1, lr=0.0001, patience=5, n_runs=3, drop_out=0.1, gpu=0, node_dim=100, time_dim=100, backprop_every=1, use_memory=True, embedding_module='graph_attention', message_function='identity', memory_updater='gru', aggregator='last', memory_update_at_end=False, message_dim=100, memory_dim=172, different_new_nodes=False, uniform=False, randomize_features=False, use_destination_embedding_in_message=False, use_source_embedding_in_message=False, dyrep=False)
# The dataset has 157474 interactions, involving 9227 different nodes
# The training dataset has 79202 interactions, involving 5904 different nodes
# The validation dataset has 23621 interactions, involving 3256 different nodes
# The test dataset has 23621 interactions, involving 3564 different nodes
# The new node validation dataset has 11742 interactions, involving 2134 different nodes
# ...
